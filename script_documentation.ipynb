# %%
import csv
import re
import pandas as pd
import networkx as nx
import json
from networkx.algorithms import node_classification

# %%
def dicionario_csv(arquivo):
    # Abre o arquivo CSV em modo de leitura
    with open(arquivo, mode='r', newline='', encoding='UTF-8') as arquivo_csv_:
        # Cria um leitor CSV
        leitor_csv = csv.DictReader(arquivo_csv_)
        dicionario_de_dados = {}

        # Itera sobre as linhas do arquivo CSV
        for line in leitor_csv:
            # Obtém a chave e o valor da linha
            chave = line['HASHTAG']
            valor = line['ORIENTATION']

            # Adiciona a chave e o valor ao dicionário
            dicionario_de_dados[chave] = valor

    # Agora, dicionario_de_dados contém os dados do CSV como um dicionário
    # onde as chaves são da primeira coluna e os valores são da segunda coluna
    return dicionario_de_dados

# %%
def ler_json_e_transformar_em_lista(nome_arquivo):
    try:
        with open(nome_arquivo, 'r', encoding='utf-8') as arquivo:
            dados = json.load(arquivo)
            if isinstance(dados, list):
                return dados
            else:
                print("O arquivo JSON não contém uma lista.")
                return []
    except FileNotFoundError:
        print(f"Arquivo '{nome_arquivo}' não encontrado.")
        return []
    except json.JSONDecodeError:
        print(f"Erro ao decodificar o arquivo JSON '{nome_arquivo}'.")
        return []

# %%
# Função para identificar e separar hashtags em um tweet
def extrair_hashtags(tweet_text):
    # Usando uma expressão regular para encontrar todas as hashtags começando com "#"
    hashtags_list = re.findall(r'#\w+', tweet_text)
    return hashtags_list

# %% [markdown]
# Exatraindo as hashtags de todos os tweets coletados para realizar a análise

# %%
def data_set():
    # Lista com todos os tweets
    lista1 = ler_json_e_transformar_em_lista('data-set-twitter-elections/scraped_tweets_09_16_22.json')
    lista2 = ler_json_e_transformar_em_lista('data-set-twitter-elections/scraped_tweets_09_23_22.json')
    lista3 = ler_json_e_transformar_em_lista('data-set-twitter-elections/scraped_tweets_09_30_22.json')
    lista4 = ler_json_e_transformar_em_lista('data-set-twitter-elections/scraped_tweets_10_07_22.json')
    lista5 = ler_json_e_transformar_em_lista('data-set-twitter-elections/scraped_tweets_10_14_22.json')
    lista6 = ler_json_e_transformar_em_lista('data-set-twitter-elections/scraped_tweets_10_21_22.json')
    lista7 = ler_json_e_transformar_em_lista('data-set-twitter-elections/scraped_tweets_10_28_22.json')
    lista8 = ler_json_e_transformar_em_lista('data-set-twitter-elections/scraped_tweets_11_04_22.json')
    lista9 = ler_json_e_transformar_em_lista('data-set-twitter-elections/scraped_tweets_11_11_22.json')
    lista_total = lista1 + lista2 + lista3 + lista4 + lista5 + lista6 + lista7 + lista8 + lista9
    lista = []

    for tweet in lista_total:
        if len(extrair_hashtags(tweet['full_text'])) >= 1:
            hashtags_ = extrair_hashtags(tweet['full_text'])
            hashtag = []

            if len(hashtags_) >= 1:
                for item_ in hashtags_:
                    item_ = item_.replace('#', '')
                    hashtag.append(item_)

            lista.append([tweet['full_text'], ' '.join(hashtag)])

    # Nome do arquivo CSV de destino
    nome_arquivo = "dados.csv"

    # Escreva a lista de dados em um arquivo CSV
    with open(nome_arquivo, mode="w", encoding="utf-8") as arquivo:
        escritor_csv_ = csv.writer(arquivo, delimiter=",")

        # Escreva cada linha da lista como uma linha no arquivo CSV
        for linha_ in lista:
            if any(linha_):
                escritor_csv_.writerow(linha_)

    print(f"Arquivo CSV '{nome_arquivo}' criado com sucesso.")

# %% [markdown]
# Carregando os dados das hashtags que já haviam sido caracterizadas manualmente e criando o objeto de grafo

# %%
# Carregue seus dados de hashtags
data = pd.read_csv('dados.csv')

# Crie um objeto de grafo (para representar as co-ocorrências)
G = nx.Graph()
caracterized_hashtags = dicionario_csv('hashtags_populares.csv')
lista_hashtags = []

# %% [markdown]
# Criando um grafo onde os nós são hashtags e as arestas representam a co-ocorrência de hashtags em tweets. As hashtags podem ser caracterizadas manualmente e associadas a rótulos específicos, e o peso nas arestas registra quantas vezes as hashtags ocorrem juntas em tweets diferentes. Isso permite a análise de padrões de co-ocorrência entre hashtags.

# %%
# Itere sobre cada linha do seu conjunto de dados
for index, row in data.iterrows():
    hashtags = row['HASHTAG'].split()  # Supondo que suas hashtags estejam em uma única coluna separada por espaços

    # Adicione as hashtags como nós do grafo
    for item in hashtags:
        lista_hashtags.append(item)
        if item in caracterized_hashtags:  # Caso a hashtag já tenha sido carcterizada manualmente
            G.add_node(item, label=caracterized_hashtags[item])
        else:
            G.add_node(item)

    # Crie arestas entre todas as combinações de hashtags em um único tweet
    for i in range(len(hashtags)):
        for j in range(i + 1, len(hashtags)):
            # Verifique se a aresta já existe e, se existir, aumente o peso
            if G.has_edge(hashtags[i], hashtags[j]):
                G[hashtags[i]][hashtags[j]]['weight'] += 1
            else:
                G.add_edge(hashtags[i], hashtags[j], weight=1)

# %% [markdown]
# Caracterização das hashtags que ainda não foram caracterizadas utilizando Harmonic Function

# %%
predicted = node_classification.harmonic_function(G)

lista_csv = []  # Lista para adicionar as hashtags caracterizadas, que serão salvas em arquivo csv
# Nome do arquivo CSV de destino
arq = "nome_arquivo.csv"

# %% [markdown]
# Imprima os nós com seus rótulos previstos

# %%
for node, label in zip(G.nodes, predicted):
    print(f"Hashtag: {node}, Orientation: {label}")
    lista_csv.append([node, label])
# Out:
# Hashtag: TimeDoLula, Orientation: L
# Hashtag: 13DiasParaVotar13, Orientation: L
# Hashtag: LulaPresidente13, Orientation: L
# Hashtag: LulaLadraoSeuLugarENaPrisao, Orientation: R
# Hashtag: PrefiroCiro12, Orientation: N
# Hashtag: jornaldamanha, Orientation: L
# Hashtag: 3em1, Orientation: L
# Hashtag: ospingosnosis, Orientation: L
# Hashtag: LulaPresidente, Orientation: L
# Hashtag: BolsonaroNaCadeia, Orientation: L
# Hashtag: PCdoBcomLula, Orientation: L
# Hashtag: LulaNo1ºTurno, Orientation: L
# Hashtag: BrasilDaEsperanca, Orientation: L
# Hashtag: CiroNoRatinho, Orientation: L
# Hashtag: VoteNoTerceiro, Orientation: L
# Hashtag: OPoder, Orientation: R
# Hashtag: brasil, Orientation: N
# Hashtag: silas, Orientation: R
# Hashtag: malafaia, Orientation: R
# Hashtag: londres, Orientation: R
# Hashtag: bolsonaro, Orientation: R
# Hashtag: jairbolsonaro, Orientation: N
# Hashtag: eleições2022, Orientation: L
# Hashtag: eleição, Orientation: R
# Hashtag: LulaNoPrimeiroTurno, Orientation: L
# Hashtag: BolsonaroNoPrimeiroTurno22, Orientation: R
# Hashtag: CerradoNoSenado180, Orientation: L
# Hashtag: Eleições2022, Orientation: N
# Hashtag: LULA, Orientation: L
# Hashtag: LulaEoPTjaNo1ºTurno, Orientation: L
# Hashtag: LulaNo1oturno, Orientation: L
# Hashtag: BolsonaroNoPrimeiroTurno, Orientation: R
# Hashtag: Política, Orientation: N
# Hashtag: Brasil, Orientation: N
# Hashtag: Eleicoes2022, Orientation: N
# Hashtag: ForaBolsonaro, Orientation: L
# Hashtag: Lula, Orientation: L
# Hashtag: Ricardo, Orientation: L
# Hashtag: Vené, Orientation: L
# Hashtag: Faltam13dias, Orientation: L
# Hashtag: notícias, Orientation: R
# Hashtag: g1, Orientation: N
# Hashtag: Twibbon, Orientation: L
# Hashtag: URGENTE, Orientation: N
# Hashtag: PrefiroCiro, Orientation: N
# Hashtag: Virada12, Orientation: N
# Hashtag: CiroPresidente12, Orientation: N
# Hashtag: SintectRJ, Orientation: L
# Hashtag: Freixo, Orientation: L
# Hashtag: ElizabethII, Orientation: L
# Hashtag: NewProfilePic, Orientation: L
# Hashtag: FórumOnzeeMeia, Orientation: L
# Hashtag: afazenda14, Orientation: L
# Hashtag: pantanal, Orientation: N
# Hashtag: tvglobo, Orientation: N
# Hashtag: Globo, Orientation: R
# Hashtag: Encontro, Orientation: L
# Hashtag: maisvoce, Orientation: L
# Hashtag: BiaMiranda, Orientation: L
# Hashtag: Meodeusssssssss, Orientation: L
# Hashtag: R7, Orientation: R
# Hashtag: politica, Orientation: L
# Hashtag: Ciro2022, Orientation: N
# Hashtag: CiroOuNulo, Orientation: N
# Hashtag: drudge, Orientation: L
# Hashtag: lulabara, Orientation: L
# Hashtag: BolsonaroReeleitoEm2022, Orientation: R
# Hashtag: LulaPresidente2022, Orientation: L
# Hashtag: España, Orientation: L
# Hashtag: PesquisaEleitoral, Orientation: N
# Hashtag: Bolsonaro, Orientation: R
# Hashtag: polarização, Orientation: N
# Hashtag: Corrupção, Orientation: N
# Hashtag: QueenElizabeth, Orientation: L
# Hashtag: eleicoes, Orientation: N
# Hashtag: seebdourados, Orientation: N
# Hashtag: bancários, Orientation: N
# Hashtag: habitação, Orientation: N
# Hashtag: LeeDesdeCuba, Orientation: L
# Hashtag: BrasildaEsperança, Orientation: L
# Hashtag: BolsonaroEmLondres, Orientation: R
# Hashtag: ViradaRJ, Orientation: L
# Hashtag: Repost, Orientation: L
# Hashtag: AldearAPolítica, Orientation: L
# Hashtag: DemarcaçãoJá, Orientation: L
# Hashtag: celiaxakriaba5088, Orientation: L
# Hashtag: Lula13, Orientation: L
# Hashtag: LulaEoPToBrasilTemPressa, Orientation: L
# Hashtag: BrasilDaEsperança, Orientation: L
# Hashtag: ColetivaElas, Orientation: L
# Hashtag: agoraéquesãoELAS, Orientation: L
# Hashtag: GobiernoDeSoluciones, Orientation: L
# Hashtag: Lula13no1oTurno, Orientation: L
# Hashtag: TikTok, Orientation: L
# Hashtag: PTNuncaMais, Orientation: L
# Hashtag: LulaLixo, Orientation: R
# Hashtag: Gasolina, Orientation: R
# Hashtag: JoaoAlfredo5001, Orientation: L
# Hashtag: gasolina, Orientation: R
# Hashtag: portalmanaos, Orientation: R
# Hashtag: pesquisa, Orientation: R
# Hashtag: PesquisaBTG, Orientation: N
# Hashtag: Pesquisaeleitoral, Orientation: N
# Hashtag: Eleicoes, Orientation: N
# Hashtag: MariaBethania, Orientation: L
# Hashtag: EnioVerri1330, Orientation: L
# Hashtag: NoAmazonasÉAssim, Orientation: L
# Hashtag: lula, Orientation: L
# Hashtag: bozo, Orientation: L
# Hashtag: 昨日, Orientation: L
# Hashtag: ランチ, Orientation: L
# Hashtag: 漁港, Orientation: L
# Hashtag: 夫婦, Orientation: L
# Hashtag: 写真好きな人と繫がりたい, Orientation: L
# Hashtag: 写真撮ってる人と繫がりたい, Orientation: L
# Hashtag: oğuzholding, Orientation: L
# Hashtag: oğuzgıda, Orientation: L
# Hashtag: enesörer, Orientation: L
# Hashtag: pazarpayı, Orientation: L
# Hashtag: ihracat, Orientation: L
# Hashtag: yerliüretim, Orientation: L
# Hashtag: milliüretim, Orientation: L
# Hashtag: içecekpazarı, Orientation: L
# Hashtag: influencer, Orientation: L
# Hashtag: MondayMotivation, Orientation: L
# Hashtag: 2ndWorldTour_MANIAC_Seoul_Special_UNVEIL11, Orientation: L
# Hashtag: StrayKids, Orientation: L
# Hashtag: 스트레이키즈, Orientation: L
# Hashtag: CASE143, Orientation: L
# Hashtag: MAXIDENT, Orientation: L
# Hashtag: BolsonaroReeleitoNoPrimeiroTurno, Orientation: R
# Hashtag: TarcisioGovernadorSP2022, Orientation: R
# Hashtag: VOTOutil, Orientation: L
# Hashtag: morningshow, Orientation: R
# Hashtag: eleicao2022, Orientation: R
# Hashtag: CiroPresidente, Orientation: N
# Hashtag: manifestação, Orientation: R
# Hashtag: PorIssoVotoNoCIRO, Orientation: L
# Hashtag: TempoDunia, Orientation: L
# Hashtag: sacangemnopoupatempo, Orientation: L
# Hashtag: sabesmuito, Orientation: L
# Hashtag: sexozinnocarro, Orientation: L
# Hashtag: HIPOCRITA, Orientation: L
# Hashtag: News, Orientation: R
# Hashtag: FuckBolsonaro, Orientation: L
# Hashtag: FuckFascists, Orientation: L
# Hashtag: FCKNZS, Orientation: L
# Hashtag: Bolsonaro22, Orientation: R
# Hashtag: Luladrao, Orientation: R
# Hashtag: eLeDeLADRAO, Orientation: R
# Hashtag: BrasilACORDOU, Orientation: R
# Hashtag: EsquerdaCriminosa, Orientation: R
# Hashtag: BrasilLIVRE, Orientation: R
# Hashtag: BolsonaroTemRazao, Orientation: R
# Hashtag: direita, Orientation: R
# Hashtag: BolsonaroReelected, Orientation: R
# Hashtag: BolsonaroReeleito, Orientation: R
# Hashtag: Bolsonaro2022, Orientation: R
# Hashtag: DharmaNaMídia, Orientation: L
# Hashtag: ZeeNuNew, Orientation: L
# Hashtag: poupettekenza, Orientation: L
# Hashtag: goLOUD, Orientation: R
# Hashtag: HouseOfTheDragon, Orientation: R
# Hashtag: BDSP, Orientation: R
# Hashtag: BailaViniJr, Orientation: R
# Hashtag: ViolaDavis, Orientation: R
# Hashtag: AtleticodeMadrid, Orientation: R
# Hashtag: BLOGteleSUR, Orientation: L
# Hashtag: JavierTolcachier, Orientation: L
# Hashtag: atelierpawlick, Orientation: L
# Hashtag: pawlick, Orientation: L
# Hashtag: luhanapawlick, Orientation: L
# Hashtag: altamoda, Orientation: L
# Hashtag: FechadosComBolsonaroAte2026, Orientation: L
# Hashtag: ForaBolsonaroGenocida, Orientation: L
# Hashtag: Ciro12, Orientation: N
# Hashtag: NovaFotoDePerfil, Orientation: L
# Hashtag: Resistencia1627Dias, Orientation: L
# Hashtag: BolsonaroNuncaMais, Orientation: L
# Hashtag: bolsonaroworldshame, Orientation: L
# Hashtag: JairBolsonaro22, Orientation: R
# Hashtag: criança, Orientation: R
# Hashtag: LulaLadrao, Orientation: R
# Hashtag: mulherescombolsonaro, Orientation: R
# Hashtag: BolsonaroOrgulhoDoBrasil, Orientation: R
# Hashtag: NoticiasHonduras, Orientation: L
# Hashtag: PeriodismoU, Orientation: L
# Hashtag: fantastico, Orientation: L
# Hashtag: corlu, Orientation: L
# Hashtag: FuneralRainha, Orientation: L
# Hashtag: compartilheaverdade, Orientation: L
# Hashtag: 13, Orientation: L
# Hashtag: lulapresidente, Orientation: L
# Hashtag: lula13, Orientation: L
# Hashtag: fazol, Orientation: L
# Hashtag: vote13, Orientation: L
# Hashtag: votelula, Orientation: L
# Hashtag: lulacomchuchu, Orientation: L
# Hashtag: CapitaoDoPovoVaiVencerDeNovo, Orientation: L
# Hashtag: NAYEON, Orientation: L
# Hashtag: TWICE, Orientation: L
# Hashtag: 트와이스, Orientation: L
# Hashtag: VEREADOR, Orientation: L
# Hashtag: GARIS, Orientation: L
# Hashtag: BOLSONARO, Orientation: L
# Hashtag: LulaAlckmin, Orientation: L
# Hashtag: HenriqueMeirelles, Orientation: L
# Hashtag: PlenoNews, Orientation: L
# Hashtag: CIRONORATINHO, Orientation: L
# Hashtag: PT13, Orientation: L
# Hashtag: LulaEoPTUnicaViaJaNo1ºTurno, Orientation: L
# Hashtag: PEC32Não, Orientation: L
# Hashtag: PL2258NÃO, Orientation: L
# Hashtag: PrefiroCiroPresidente12, Orientation: N
# Hashtag: JairBolsonaro, Orientation: R
# Hashtag: JairBolsonaro17, Orientation: R
# Hashtag: Cristão, Orientation: L
# Hashtag: 223, Orientation: L
# Hashtag: soniasp5088, Orientation: L
# Hashtag: spéterraindígena, Orientation: L
# Hashtag: professordudu, Orientation: L
# Hashtag: deputadoestadual, Orientation: L
# Hashtag: vote13123, Orientation: L
# Hashtag: detodasaslutas, Orientation: L
# Hashtag: ListadechefesdeEstadorecebidosporJairBolsonaro, Orientation: L
# Hashtag: wikipedia, Orientation: L
# Hashtag: eleicoes2022, Orientation: N
# Hashtag: eduardobolsonaro, Orientation: R
# Hashtag: claudiofernando, Orientation: R
# Hashtag: bolsomito, Orientation: R
# Hashtag: fechadocombolsonaro, Orientation: R
# Hashtag: claudioferndando22380, Orientation: R
# Hashtag: bolsonaromerepresenta, Orientation: R
# Hashtag: bolsonaropresidente, Orientation: R
# Hashtag: ONU, Orientation: L
# Hashtag: I3rasil, Orientation: L
# Hashtag: gugaenergumeno, Orientation: L
# Hashtag: SegundaChamada, Orientation: L
# Hashtag: VaiSerNoPrimeiroTurno, Orientation: L
# Hashtag: mornigshow, Orientation: L
# Hashtag: 13dias, Orientation: L
# Hashtag: brandão40, Orientation: L
# Hashtag: dino400, Orientation: L
# Hashtag: edicao10, Orientation: R
# Hashtag: cnnBrasil, Orientation: R
# Hashtag: oglobo, Orientation: R
# Hashtag: camaradeputados, Orientation: R
# Hashtag: senadofederal, Orientation: R
# Hashtag: diariodepernambuco, Orientation: R
# Hashtag: uolnews, Orientation: R
# Hashtag: estadodeminas, Orientation: R
# Hashtag: DireitaUnida, Orientation: R
# Hashtag: diariodonordeste, Orientation: R
# Hashtag: JovemPanNews, Orientation: R
# Hashtag: bandnewsfm, Orientation: R
# Hashtag: folha, Orientation: R
# Hashtag: estadao, Orientation: R
# Hashtag: bandnewstv, Orientation: R
# Hashtag: encontro, Orientation: L
# Hashtag: ex, Orientation: L
# Hashtag: presidenciaveis, Orientation: L
# Hashtag: apoio, Orientation: L
# Hashtag: BolsonaroBurro, Orientation: R
# Hashtag: LibraéMaiorQueReal, Orientation: R
# Hashtag: MorningShow, Orientation: R
# Hashtag: VotePreto, Orientation: L
# Hashtag: NeivaLazzarotto50001, Orientation: L
# Hashtag: DeputadaEstadual, Orientation: L
# Hashtag: TamyresFilgueira5001, Orientation: L
# Hashtag: DeputadaFederal, Orientation: L
# Hashtag: HaddadGovernador13, Orientation: L
# Hashtag: MarcioFranca400Senador, Orientation: L
# Hashtag: NiltoTatto1353Federal, Orientation: L
# Hashtag: basile, Orientation: L
# Hashtag: caminhada, Orientation: L
# Hashtag: pt, Orientation: L
# Hashtag: lulano1oturno, Orientation: L
# Hashtag: INSTA, Orientation: L
# Hashtag: Seungstagram, Orientation: L
# Hashtag: gimondardodepfederal65, Orientation: L
# Hashtag: ELEIÇÕES2022, Orientation: L
# Hashtag: tchutchucadocentrão, Orientation: L
# Hashtag: EleNao, Orientation: L
# Hashtag: Opinião, Orientation: L
# Hashtag: Lula2022, Orientation: L
# Hashtag: Panico, Orientation: L
# Hashtag: VittarloversComBolsonsro, Orientation: L
# Hashtag: JN, Orientation: R
# Hashtag: Fantástico, Orientation: L
# Hashtag: Goiania, Orientation: L
# Hashtag: Malafaia, Orientation: R
# Hashtag: Religião, Orientation: R
# Hashtag: PortaliG, Orientation: L
# Hashtag: VaiSerNoPrimeiroTurno22, Orientation: L
# Hashtag: CNNnasEleições, Orientation: R
# Hashtag: BolsonaroReeleitoNoPrimeiroTurno2022, Orientation: L
# Hashtag: AuxilioGás, Orientation: R
# Hashtag: FamiliasPobres, Orientation: R
# Hashtag: Economia, Orientation: N
# Hashtag: Fome, Orientation: R
# Hashtag: desemprego, Orientation: R
# Hashtag: Pactu, Orientation: R
# Hashtag: seebumuarama, Orientation: R
# Hashtag: umuarama, Orientation: R
# Hashtag: Londres, Orientation: N
# Hashtag: PrensaLatina, Orientation: N
# Hashtag: janones, Orientation: L
# Hashtag: monark, Orientation: L
# Hashtag: LulaGigante, Orientation: L
# Hashtag: Vote21, Orientation: L
# Hashtag: PCB21, Orientation: L
# Hashtag: SofiaManzano21, Orientation: L
# Hashtag: Sofia50Mil, Orientation: L
# Hashtag: forafamilicia, Orientation: L
# Hashtag: anfenoju, Orientation: L
# Hashtag: FechadoComBolsonaro22, Orientation: L
# Hashtag: 13DiasPraVotar13, Orientation: L
# Hashtag: IsabelII, Orientation: N
# Hashtag: 5, Orientation: L
# Hashtag: Morningsghow, Orientation: N
# Hashtag: NaoVotemNeles, Orientation: L
# Hashtag: 2deoutubro, Orientation: L
# Hashtag: lulaparapresidente, Orientation: L
# Hashtag: obrasilnãoaguentamais, Orientation: L
# Hashtag: Brazil, Orientation: N
# Hashtag: BrasildeFato, Orientation: L
# Hashtag: BOLSOANRO, Orientation: L
# Hashtag: ÉpraSeguirJuntos, Orientation: L
# Hashtag: politics, Orientation: N
# Hashtag: brazil, Orientation: N
# Hashtag: UnitedKingdom, Orientation: N
# Hashtag: QueenElizabethII, Orientation: N
# Hashtag: BrazilianPolitics, Orientation: N
# Hashtag: eleições, Orientation: N
# Hashtag: bolsonarocorrupto, Orientation: L
# Hashtag: DesculpasDoPT, Orientation: L
# Hashtag: QueroBolsonaroAte2026, Orientation: L
# Hashtag: TimeLula, Orientation: L
# Hashtag: BolsonaroGenocida, Orientation: L
# Hashtag: BolsonaroCorrupto, Orientation: L
# Hashtag: ForaBolsonaroCorrupto, Orientation: L
# Hashtag: diva, Orientation: L
# Hashtag: CiroTV, Orientation: N
# Hashtag: VEJAGente, Orientation: L
# Hashtag: Obtuso, Orientation: L
# Hashtag: 13confirma, Orientation: L
# Hashtag: lulapresidente13, Orientation: L
# Hashtag: FAKE, Orientation: L
# Hashtag: Vexame, Orientation: L
# Hashtag: bolsominios, Orientation: L
# Hashtag: STAY, Orientation: L
# Hashtag: LulaEmCuritiba, Orientation: L
# Hashtag: Voto50013, Orientation: L
# Hashtag: SouMaisColetivo, Orientation: L
# Hashtag: TurmaBoa, Orientation: L
# Hashtag: AndreSenador133, Orientation: L
# Hashtag: Lula13NoPrimeiroTurno, Orientation: L
# Hashtag: UseVerdeAmareloPraIrVotar, Orientation: L
# Hashtag: FazoL, Orientation: L
# Hashtag: SigaIF, Orientation: L
# Hashtag: InteligenciaFinanceira, Orientation: L
# Hashtag: IF, Orientation: L
# Hashtag: VamosJuntosPeloBrasil, Orientation: L
# Hashtag: sigilo, Orientation: N
# Hashtag: LulaLáMaríliaCá, Orientation: L
# Hashtag: MaríliaÉ77, Orientation: L
# Hashtag: MaríliaGovernadora77, Orientation: L
# Hashtag: ChoraPetezada, Orientation: L
# Hashtag: anodeouro, Orientation: L
# Hashtag: PNotícias, Orientation: R
# Hashtag: últimasnotícias, Orientation: R
# Hashtag: EmpurraPiatã, Orientation: R
# Hashtag: PiatãFM, Orientation: R
# Hashtag: política, Orientation: R
# Hashtag: combustível, Orientation: R
# Hashtag: inglaterra, Orientation: R
# Hashtag: vídeo, Orientation: R
# Hashtag: empresário, Orientation: R
# Hashtag: aposta, Orientation: R
# Hashtag: JornaldaCultura, Orientation: L
# Hashtag: DouglasBelchior1375, Orientation: L
# Hashtag: jair_bolsonaro, Orientation: L
# Hashtag: international, Orientation: L
# Hashtag: elizabeth_ii, Orientation: L
# Hashtag: condolences, Orientation: L
# Hashtag: president, Orientation: L
# Hashtag: TaNaHoraDeVoceOlharProCiro, Orientation: L
# Hashtag: noticieromam, Orientation: N
# Hashtag: emisorasunidas, Orientation: N
# Hashtag: CNNBrasil, Orientation: R
# Hashtag: AlessandroTrindade13163, Orientation: L
# Hashtag: AndreCeciliano133, Orientation: L
# Hashtag: BOLSONARO2022, Orientation: N
# Hashtag: ANTONIOTERTUS, Orientation: N
# Hashtag: 43, Orientation: L
# Hashtag: euvotoemprojeto, Orientation: L
# Hashtag: hotd, Orientation: L
# Hashtag: faltam13, Orientation: R
# Hashtag: TELEPROMPTER, Orientation: L
# Hashtag: antalyatraveﬅi, Orientation: L
# Hashtag: Lula13Presidente, Orientation: L
# Hashtag: LulaPresidentePrimeiroTurno, Orientation: L
# Hashtag: queensfuneral, Orientation: N
# Hashtag: ParadaMilitar2022, Orientation: N
# Hashtag: PraTodoseTodasVerem, Orientation: L
# Hashtag: LulaEdegar13, Orientation: L
# Hashtag: EdegarPretto13, Orientation: L
# Hashtag: mijonas, Orientation: L
# Hashtag: BolsonaroVagabundo, Orientation: L
# Hashtag: ForaBolsonaroVagabundo, Orientation: L
# Hashtag: tchutchucaDoCentrao, Orientation: L
# Hashtag: Portugal, Orientation: L
# Hashtag: SabatinaCBNRecife, Orientation: L
# Hashtag: 13rasil, Orientation: L
# Hashtag: vote, Orientation: L
# Hashtag: BolsonaroPresidente22, Orientation: R
# Hashtag: CarlosJordyDeputadoFederal2211, Orientation: R
# Hashtag: LulaEoPTdemocraciaEpaz, Orientation: L
# Hashtag: BRAZIL, Orientation: N
# Hashtag: lulaflix, Orientation: L
# Hashtag: NFTGiveaway, Orientation: L
# Hashtag: NFT, Orientation: L
# Hashtag: MentalHealthMatters, Orientation: L
# Hashtag: NFTGiveaways, Orientation: L
# Hashtag: NFTs, Orientation: L
# Hashtag: NFTcollections, Orientation: L
# Hashtag: NFTMarketplace, Orientation: L
# Hashtag: NFTCommunity, Orientation: L
# Hashtag: GiveBack, Orientation: L
# Hashtag: opensea, Orientation: L
# Hashtag: boletimFolha, Orientation: L
# Hashtag: Eleicoes22, Orientation: L
# Hashtag: CriançasPetistas, Orientation: L
# Hashtag: PSOLcomLula, Orientation: L
# Hashtag: LULADRAO, Orientation: R
# Hashtag: Lulano1turno, Orientation: L
# Hashtag: portalimprensa, Orientation: L
# Hashtag: CiroGomes, Orientation: N
# Hashtag: Quaest, Orientation: R
# Hashtag: Pesquisa, Orientation: N
# Hashtag: AmazonasAtual, Orientation: R
# Hashtag: ColaAí, Orientation: L
# Hashtag: LulaEoPTtudoNoPrimeiroTurno, Orientation: L
# Hashtag: DeNada, Orientation: L
# Hashtag: TeimaLula, Orientation: L
# Hashtag: BoraLULA, Orientation: L
# Hashtag: Vote13, Orientation: L
# Hashtag: TrendingNews, Orientation: L
# Hashtag: EsseEoMeuVoto, Orientation: L
# Hashtag: AgoraEQueSaoElas, Orientation: L
# Hashtag: EsseÉMeuVoto, Orientation: L
# Hashtag: lula2022, Orientation: L
# Hashtag: oliviodutra, Orientation: L
# Hashtag: edegarpretto, Orientation: L
# Hashtag: GutoeAdão, Orientation: L
# Hashtag: osgurideviamão, Orientation: L
# Hashtag: gutodeputado, Orientation: L
# Hashtag: gutolopes, Orientation: L
# Hashtag: adao, Orientation: L
# Hashtag: adãopretto, Orientation: L
# Hashtag: DebateNoSBT, Orientation: N
# Hashtag: Encontros, Orientation: L
# Hashtag: LeandroGrass43, Orientation: L
# Hashtag: RosileneSenadora133, Orientation: L
# Hashtag: Rihanna, Orientation: L
# Hashtag: LulaLADRAOseulugarÉnaPRISÃO, Orientation: R
# Hashtag: LulaLADRAO, Orientation: R
# Hashtag: EsseEMeuVoto, Orientation: L
# Hashtag: Notícias, Orientation: N
# Hashtag: presidencia, Orientation: N
# Hashtag: candidato, Orientation: L
# Hashtag: Noticias, Orientation: N
# Hashtag: ForaBolsonaroeSuaQuadrilha, Orientation: L
# Hashtag: Dia1VaiSerGigante, Orientation: L
# Hashtag: MotoCarreatasDaVitoria, Orientation: L
# Hashtag: 𝑑𝑜𝑚𝑖𝑛𝑔𝑜𝑑𝑒𝑡𝑟𝑒𝑚𝑢𝑟𝑎𝑠𝑑𝑣, Orientation: L
# Hashtag: LulaDePrimeira, Orientation: L
# Hashtag: PrefiroLula13, Orientation: L
# Hashtag: VOTOUTILDERROTAOINUTIL, Orientation: L
# Hashtag: VotoUtil, Orientation: L
# Hashtag: LulaNaPortela, Orientation: L
# Hashtag: NetinhoOficialBrasileiro, Orientation: R
# Hashtag: NetinhoDaBahia, Orientation: R
# Hashtag: Netinho, Orientation: R
# Hashtag: DeputadoFederal, Orientation: R
# Hashtag: Salvador, Orientation: R
# Hashtag: bahia, Orientation: R
# Hashtag: PINTOAWARDS, Orientation: L
# Hashtag: Dia_2_é_BOLSONARO_22, Orientation: L
# Hashtag: Ciro, Orientation: N
# Hashtag: LulaPeloBrasilHaddadPorSP, Orientation: L
# Hashtag: LulaNoSBT, Orientation: L
# Hashtag: LulaNoRatinho, Orientation: L
# Hashtag: LulaEmMadureira, Orientation: L
# Hashtag: lulaemcuritiba, Orientation: L
# Hashtag: lulaembelem, Orientation: L
# Hashtag: lulanacnn, Orientation: L
# Hashtag: lulanaband, Orientation: L
# Hashtag: VazaJato, Orientation: L
# Hashtag: LulaNoRS, Orientation: L
# Hashtag: bolsonaro2022, Orientation: R
# Hashtag: noticiasbrasil, Orientation: R
# Hashtag: josemonteir, Orientation: R
# Hashtag: polifica, Orientation: R
# Hashtag: Familia, Orientation: R
# Hashtag: cristaos, Orientation: R
# Hashtag: pastores, Orientation: R
# Hashtag: BolsonaroReeleito2022, Orientation: R
# Hashtag: bolsonaroreeleito2022, Orientation: R
# Hashtag: LulaPressidente13, Orientation: L
# Hashtag: gnnoticias, Orientation: N
# Hashtag: sorayatraira, Orientation: L
# Hashtag: ls, Orientation: L
# Hashtag: Argentina, Orientation: L
# Hashtag: EitaglóriasdeDeus, Orientation: L
# Hashtag: ELEIÇÕES, Orientation: L
# Hashtag: shorts, Orientation: R
# Hashtag: edegargovernador13, Orientation: L
# Hashtag: oliviosenador131, Orientation: L
# Hashtag: BrasilMelhor, Orientation: N
# Hashtag: JulioNafe, Orientation: N
# Hashtag: Jesus, Orientation: N
# Hashtag: forahelder, Orientation: L
# Hashtag: heldernacadeia, Orientation: L
# Hashtag: PTnuncaMais, Orientation: R
# Hashtag: BolsonaroReeleito22, Orientation: R
# Hashtag: EleccionesBrasil, Orientation: N
# Hashtag: RubensRicupero, Orientation: N
# Hashtag: jornaldapb, Orientation: L
# Hashtag: Mundo, Orientation: R
# Hashtag: sociedade, Orientation: N
# Hashtag: auxilio, Orientation: N
# Hashtag: VoteBolsonaro22, Orientation: L
# Hashtag: UmRealUmEleitor, Orientation: L
# Hashtag: 1, Orientation: N
# Hashtag: turmaboa, Orientation: N
# Hashtag: ColunaCH, Orientation: L
# Hashtag: DiarioDoPoder, Orientation: L
# Hashtag: Internacionales, Orientation: N
# Hashtag: EhliyetAffı, Orientation: L
# Hashtag: Eleições, Orientation: R
# Hashtag: vemai, Orientation: L
# Hashtag: lulapresidente2022, Orientation: L
# Hashtag: ottoalencar, Orientation: L
# Hashtag: jerônimo2022, Orientation: L
# Hashtag: democracia, Orientation: L
# Hashtag: forabolsonaro, Orientation: L
# Hashtag: elenão, Orientation: L
# Hashtag: INTERNACIONAL, Orientation: L
# Hashtag: DebatePresidente, Orientation: N
# Hashtag: edicaodas15h, Orientation: L
# Hashtag: globonews, Orientation: R
# Hashtag: CentralDasEleicoes, Orientation: R
# Hashtag: CNNnasEleicoes, Orientation: R
# Hashtag: uol, Orientation: R
# Hashtag: LulaemMadureira, Orientation: L
# Hashtag: LulaNo1oTurno, Orientation: L
# Hashtag: ViraVoto, Orientation: L
# Hashtag: PatriaGrande, Orientation: L
# Hashtag: lulinhapazeamor, Orientation: L
# Hashtag: bolsonarismo, Orientation: R
# Hashtag: tchutchucadebolsonaro, Orientation: L
# Hashtag: lula13noprimeiroturno, Orientation: L
# Hashtag: AlexandreSilveira555, Orientation: L
# Hashtag: faltam7dias, Orientation: L
# Hashtag: faltam7, Orientation: L
# Hashtag: esseemeuvoto, Orientation: L
# Hashtag: VOTEJB22, Orientation: R
# Hashtag: VotoUtilDerrotaoInutil, Orientation: L
# Hashtag: lulu, Orientation: L
# Hashtag: brasilia, Orientation: R
# Hashtag: CiegodeAvila, Orientation: N
# Hashtag: CubaPorLasFamilias, Orientation: N
# Hashtag: CodigoDeAmor, Orientation: N
# Hashtag: PadreKelmon2026, Orientation: R
# Hashtag: contagemregressiva, Orientation: N
# Hashtag: B22, Orientation: R
# Hashtag: bolsonaro22, Orientation: R
# Hashtag: RJ, Orientation: N
# Hashtag: RiodeJaneiro, Orientation: N
# Hashtag: 021, Orientation: R
# Hashtag: Eleicao2022, Orientation: N
# Hashtag: MayaLink, Orientation: L
# Hashtag: WikiLink, Orientation: L
# Hashtag: RihannaNoSuperBowl, Orientation: L
# Hashtag: desafiopalindromo75, Orientation: L
# Hashtag: palindromo, Orientation: L
# Hashtag: FortniteParadise, Orientation: N
# Hashtag: AFazenda, Orientation: L
# Hashtag: Lulabundao, Orientation: L
# Hashtag: LulaLadrão, Orientation: R
# Hashtag: DerechaMiserable, Orientation: L
# Hashtag: DebateNaGlobo, Orientation: N
# Hashtag: FORABOlsonaro, Orientation: L
# Hashtag: 7DeSetembroVaiSerGigante, Orientation: R
# Hashtag: LulaJa, Orientation: L
# Hashtag: LulaEmItaquera, Orientation: L
# Hashtag: Pantanal, Orientation: L
# Hashtag: RihannanoSuperBowl, Orientation: L
# Hashtag: Debate, Orientation: R
# Hashtag: ÉLulaLáeFátimaCá, Orientation: L
# Hashtag: LulaPresidenteDoBrasil, Orientation: L
# Hashtag: agroshow, Orientation: R
# Hashtag: agronegócio, Orientation: R
# Hashtag: PrudutorRural, Orientation: R
# Hashtag: PT, Orientation: L
# Hashtag: esseémeuvoto, Orientation: L
# Hashtag: lulaefreixo, Orientation: L
# Hashtag: Freixo40, Orientation: L
# Hashtag: LulaNo1ºTurno13, Orientation: L
# Hashtag: TRANSAÇÕESalpinistasATÍPICAS, Orientation: L
# Hashtag: paulista, Orientation: L
# Hashtag: avpaulista, Orientation: L
# Hashtag: 13livrosvermelhos, Orientation: L
# Hashtag: desafiodos13livros, Orientation: L
# Hashtag: PrimeiroTurno, Orientation: L
# Hashtag: CirotchutchucadoBolsonaro, Orientation: L
# Hashtag: CiroTchutchucaDoBozo, Orientation: L
# Hashtag: cirotchutchuca, Orientation: L
# Hashtag: followtrick, Orientation: L
# Hashtag: Cironaro, Orientation: L
# Hashtag: FORABOLSONARO, Orientation: L
# Hashtag: NoArNaCBN, Orientation: N
# Hashtag: prefiromical, Orientation: R
# Hashtag: deputadaoficial, Orientation: R
# Hashtag: povodedeus, Orientation: R
# Hashtag: vozqueclamapovo, Orientation: R
# Hashtag: soumical, Orientation: R
# Hashtag: micaltáon, Orientation: R
# Hashtag: maranhão, Orientation: R
# Hashtag: deus, Orientation: L
# Hashtag: pátria, Orientation: R
# Hashtag: família, Orientation: L
# Hashtag: tocombolsonaro, Orientation: R
# Hashtag: micalénecessaria, Orientation: R
# Hashtag: PadreKelmonNoDebateDaGlobo, Orientation: L
# Hashtag: 8216, Orientation: L
# Hashtag: 8217, Orientation: L
# Hashtag: LulaPrimeiroTurno, Orientation: L
# Hashtag: AlertaElectoral, Orientation: L
# Hashtag: Time13011, Orientation: L
# Hashtag: DeputadoEstadualMaurici13011, Orientation: L
# Hashtag: LULADRÃO, Orientation: L
# Hashtag: Bolsonaro22ReeleitoNoPrimeiroTurno, Orientation: L
# Hashtag: 237, Orientation: L
# Hashtag: LulaNaCadeia, Orientation: N
# Hashtag: SINFindeSemana, Orientation: L
# Hashtag: Comicios, Orientation: L
# Hashtag: SuperBowl, Orientation: L
# Hashtag: ÉCiroouNulo, Orientation: L
# Hashtag: BelleBelinhacomLula, Orientation: L
# Hashtag: Anotem, Orientation: L
# Hashtag: lovebirds, Orientation: L
# Hashtag: bears, Orientation: L
# Hashtag: ForeverHome, Orientation: L
# Hashtag: Ministérios, Orientation: L
# Hashtag: NunoVasconcellos, Orientation: L
# Hashtag: dido, Orientation: L
# Hashtag: VotoUtilPraDerrotarOInutil, Orientation: L
# Hashtag: RevistaFórum, Orientation: L
# Hashtag: TVFórum, Orientation: L
# Hashtag: WORLD_NEWS, Orientation: L
# Hashtag: foraBolsonaro, Orientation: L
# Hashtag: EsquerdaSegueEsquerda, Orientation: L
# Hashtag: Ciro12Presidente, Orientation: N
# Hashtag: canalhas, Orientation: L
# Hashtag: Vote13TireBolsonaro, Orientation: L
# Hashtag: lulaja, Orientation: L
# Hashtag: HadisNajafi, Orientation: L
# Hashtag: حدیث_نجفی, Orientation: L
# Hashtag: مهسا_امینی, Orientation: L
# Hashtag: CiroContraOSistema, Orientation: N
# Hashtag: RespeitaMeuVoto, Orientation: L
# Hashtag: Poder360, Orientation: L
# Hashtag: CNNLiveUpdate, Orientation: R
# Hashtag: Pocket, Orientation: L
# Hashtag: LulaLáDécioAqui, Orientation: L
# Hashtag: santacatarina, Orientation: L
# Hashtag: governador, Orientation: L
# Hashtag: ItapoaComLula, Orientation: L
# Hashtag: juntospelobrasil, Orientation: L
# Hashtag: juntosporsc, Orientation: L
# Hashtag: LulaArregao, Orientation: L
# Hashtag: TSE, Orientation: N
# Hashtag: live, Orientation: R
# Hashtag: lulanoprimeiroturno, Orientation: L
# Hashtag: brasildaesperança, Orientation: L
# Hashtag: paris, Orientation: L
# Hashtag: cirogomes, Orientation: R
# Hashtag: ciro, Orientation: L
# Hashtag: LIBERDADE, Orientation: N
# Hashtag: ORDEMEPROGRESSO, Orientation: N
# Hashtag: PROSPERIDADE, Orientation: N
# Hashtag: FAMÍLIA, Orientation: N
# Hashtag: VALORES, Orientation: N
# Hashtag: PÁTRIA, Orientation: N
# Hashtag: LulaNoPrimeiroTurno13, Orientation: L
# Hashtag: EsquerdistaSegueEsquerdista, Orientation: L
# Hashtag: lulanors, Orientation: L
# Hashtag: voto, Orientation: N
# Hashtag: DebatePresidente2022, Orientation: N
# Hashtag: DebateCNN, Orientation: N
# Hashtag: DebateSBT, Orientation: N
# Hashtag: DebateNoTerra, Orientation: N
# Hashtag: OGlobonasEleicoes, Orientation: N
# Hashtag: debatenacnn, Orientation: N
# Hashtag: debateestadao, Orientation: N
# Hashtag: debateparapresidente, Orientation: N
# Hashtag: LulaEMariliaArraesJuntosPorPE, Orientation: L
# Hashtag: ClaudeteAlves1388, Orientation: L
# Hashtag: VotenaPreta, Orientation: L
# Hashtag: cironaro, Orientation: L
# Hashtag: partiu, Orientation: L
# Hashtag: AcordaBrasil, Orientation: R
# Hashtag: SomosTodosBolsonaro, Orientation: R
# Hashtag: Compartilhe, Orientation: R
# Hashtag: Meuvotoé, Orientation: L
# Hashtag: Luladeprimeira, Orientation: L
# Hashtag: CarnaLula, Orientation: L
# Hashtag: freejairme, Orientation: L
# Hashtag: PINTOSAWARDS, Orientation: L
# Hashtag: PINTOSAWARD, Orientation: L
# Hashtag: onlyfans, Orientation: L
# Hashtag: onlyfansgirl, Orientation: L
# Hashtag: DahmerNetflix, Orientation: L
# Hashtag: LittleWomen, Orientation: L
# Hashtag: troconudss, Orientation: L
# Hashtag: LGBTQ, Orientation: L
# Hashtag: LGBT, Orientation: L
# Hashtag: anitta, Orientation: L
# Hashtag: jovempannews, Orientation: R
# Hashtag: Politica, Orientation: N
# Hashtag: noticias, Orientation: R
# Hashtag: fofocas, Orientation: N
# Hashtag: foralulaeBolsonaro, Orientation: L
# Hashtag: PlanaltoCentral, Orientation: L
# Hashtag: rihannasuperbowl2023, Orientation: L
# Hashtag: Brasilhexa, Orientation: L
# Hashtag: Michele, Orientation: L
# Hashtag: foragenocida, Orientation: L
# Hashtag: BolsoCiro, Orientation: L
# Hashtag: SBTBrasil, Orientation: R
# Hashtag: 200AnosDaIndependencia, Orientation: R
# Hashtag: FuturoPresidiário, Orientation: L
# Hashtag: AFazenda14, Orientation: L
# Hashtag: votoseguro, Orientation: L
# Hashtag: NordestefechadocomBolsonaro, Orientation: L
# Hashtag: EsseÉmeuVoto, Orientation: L
# Hashtag: 2x08, Orientation: L
# Hashtag: CremoneseLazio, Orientation: L
# Hashtag: Hashtag, Orientation: L
# Hashtag: LuaNo1, Orientation: L
# Hashtag: Thronicke, Orientation: R
# Hashtag: Desafio, Orientation: R
# Hashtag: DiariodoPoder, Orientation: L
# Hashtag: momentododebate, Orientation: N
# Hashtag: Soraya, Orientation: N
# Hashtag: campanha, Orientation: N
# Hashtag: ridícula, Orientation: N
# Hashtag: covardia, Orientation: N
# Hashtag: SomosTodosCapitaoJB22, Orientation: L
# Hashtag: LulaArregão, Orientation: L
# Hashtag: Orçamento, Orientation: R
# Hashtag: Governo, Orientation: R
# Hashtag: FelipeDávila, Orientation: R
# Hashtag: 244, Orientation: L
# Hashtag: ratinho, Orientation: L
# Hashtag: 気候, Orientation: L
# Hashtag: 異常気象, Orientation: L
# Hashtag: PadreKelmon, Orientation: L
# Hashtag: gameover, Orientation: L
# Hashtag: PDT, Orientation: R
# Hashtag: Noticia, Orientation: N
# Hashtag: Actualidad, Orientation: N
# Hashtag: AguajeroDigital, Orientation: N
# Hashtag: RockInRio, Orientation: L
# Hashtag: LulaNaRecord, Orientation: L
# Hashtag: LULA2022PRESIDENTE, Orientation: L
# Hashtag: EsseÉmeuvoto, Orientation: L
# Hashtag: Lulapresidente, Orientation: L
# Hashtag: UOL, Orientation: R
# Hashtag: Madureira, Orientation: L
# Hashtag: Portela, Orientation: L
# Hashtag: SimonePresidente15, Orientation: L
# Hashtag: LulaCovarde, Orientation: L
# Hashtag: GAY, Orientation: N
# Hashtag: BRASIL, Orientation: N
# Hashtag: gaysdedireita, Orientation: N
# Hashtag: gaysconservadores, Orientation: N
# Hashtag: ECONOMIALIBERAL, Orientation: N
# Hashtag: pride, Orientation: N
# Hashtag: LGBTQIA, Orientation: N
# Hashtag: haddad13governadorsp, Orientation: L
# Hashtag: França400, Orientation: L
# Hashtag: Boulos5010, Orientation: L
# Hashtag: suplicy13133, Orientation: L
# Hashtag: Eleiçoes2022, Orientation: R
# Hashtag: NemLulaNemBolsonaro, Orientation: L
# Hashtag: DanielSilveiraSenador2022, Orientation: R
# Hashtag: STFVergonhaNacional, Orientation: R
# Hashtag: LulaLadrãoNaCadeia, Orientation: R
# Hashtag: STFVergonha, Orientation: R
# Hashtag: elasim, Orientation: L
# Hashtag: elesnao, Orientation: L
# Hashtag: SóCiroVenceLula, Orientation: N
# Hashtag: BolsonaroVergonhaMundial, Orientation: L
# Hashtag: É13, Orientation: L
# Hashtag: argentina, Orientation: N
# Hashtag: CFK, Orientation: L
# Hashtag: ForzaItalia, Orientation: L
# Hashtag: LulaInRio, Orientation: L
# Hashtag: Palmeiras, Orientation: L
# Hashtag: BBNaija, Orientation: L
# Hashtag: CiroNoDebate, Orientation: N
# Hashtag: Lazio, Orientation: L
# Hashtag: HUNITA, Orientation: L
# Hashtag: Azzurri, Orientation: L
# Hashtag: NationsLeague, Orientation: L
# Hashtag: UNL, Orientation: L
# Hashtag: 266, Orientation: L
# Hashtag: BrasilComBolsonaro22, Orientation: L
# Hashtag: LuLADRAO, Orientation: R
# Hashtag: Russia, Orientation: L
# Hashtag: Arctic, Orientation: R
# Hashtag: Fracking, Orientation: R
# Hashtag: foraciro, Orientation: L
# Hashtag: EsseEmeuVoto, Orientation: L
# Hashtag: Fantastico, Orientation: R
# Hashtag: FORA, Orientation: R
# Hashtag: VotoÚtil, Orientation: L
# Hashtag: Lulanoprimeiroturno, Orientation: L
# Hashtag: DinheiroVivo, Orientation: L
# Hashtag: Amanda, Orientation: L
# Hashtag: AppleEvent, Orientation: L
# Hashtag: ChampionsLeague, Orientation: L
# Hashtag: votoutil, Orientation: L
# Hashtag: Enfermagem, Orientation: L
# Hashtag: SimoneTaSubindo, Orientation: L
# Hashtag: JB22, Orientation: L
# Hashtag: moro2022, Orientation: R
# Hashtag: LulaNuncaMais, Orientation: R
# Hashtag: MulherVotaEmMulher, Orientation: R
# Hashtag: SpaceDos24Dias, Orientation: L
# Hashtag: BOLSONARO22, Orientation: N
# Hashtag: G1, Orientation: R
# Hashtag: brasiliapodemais, Orientation: R
# Hashtag: ptbr, Orientation: R
# Hashtag: lulalivre, Orientation: R
# Hashtag: corrupcaobrmemes, Orientation: R
# Hashtag: corrupcao, Orientation: L
# Hashtag: kidbengala, Orientation: R
# Hashtag: memes, Orientation: R
# Hashtag: politicabrasil, Orientation: R
# Hashtag: ptnuncamais, Orientation: R
# Hashtag: generalpaulochagas, Orientation: R
# Hashtag: GloboNews, Orientation: R
# Hashtag: BOLSONAROREELEITO, Orientation: L
# Hashtag: ogloboesportes, Orientation: L
# Hashtag: DataPovo, Orientation: L
# Hashtag: datafolha, Orientation: L
# Hashtag: 7desetembro, Orientation: L
# Hashtag: VOTE, Orientation: R
# Hashtag: expresidiario, Orientation: R
# Hashtag: deputadafederal, Orientation: L
# Hashtag: GloboGolpista, Orientation: L
# Hashtag: Nordesteébolsonaro, Orientation: L
# Hashtag: g1Campinas, Orientation: L
# Hashtag: BolsonaroNaRedeTV, Orientation: L
# Hashtag: LulaSubiuAGasolinaCaiu, Orientation: L
# Hashtag: CopadoMundo, Orientation: L
# Hashtag: albumdacopa, Orientation: L
# Hashtag: panine, Orientation: L
# Hashtag: ForaBolsonaroMentiroso, Orientation: L
# Hashtag: Vídeo, Orientation: L
# Hashtag: estudioi, Orientation: R
# Hashtag: 1turnoLula, Orientation: L
# Hashtag: AtéAPéNósIremos, Orientation: L
# Hashtag: cirosobe, Orientation: L
# Hashtag: BolsonaroMente, Orientation: L
# Hashtag: EuacretoVcsSãoDementes, Orientation: L
# Hashtag: CNNNovoDia, Orientation: N
# Hashtag: KPWorldTourInBrazil, Orientation: L
# Hashtag: emicidanomultishow, Orientation: L
# Hashtag: ATENÇÃO, Orientation: L
# Hashtag: Doria2026, Orientation: L
# Hashtag: 8211, Orientation: L
# Hashtag: 8220, Orientation: L
# Hashtag: 8221, Orientation: L
# Hashtag: comLulapeloBrasil, Orientation: L
# Hashtag: LulaEoPT13deFioApavio, Orientation: L
# Hashtag: jornalismoimparcialmorreu, Orientation: L
# Hashtag: MuitaHipocrisia, Orientation: L
# Hashtag: NinguemSeguraO12, Orientation: N
# Hashtag: CiroNaCNN, Orientation: N
# Hashtag: Democracia, Orientation: R
# Hashtag: CiroNoPanico, Orientation: N
# Hashtag: JusticeWorldTour, Orientation: L
# Hashtag: flopou, Orientation: L
# Hashtag: patético, Orientation: L
# Hashtag: TEBETACIMADECIRO, Orientation: L
# Hashtag: OsPingosNosIs, Orientation: R
# Hashtag: LulaJaEra, Orientation: R
# Hashtag: ConexaoGlobonews, Orientation: R
# Hashtag: estúdioi, Orientation: R
# Hashtag: empauta, Orientation: R
# Hashtag: jn, Orientation: R
# Hashtag: BolsonaroMentiroso, Orientation: L
# Hashtag: BolsonaroOrgulhodoBrasil, Orientation: R
# Hashtag: Datafolha, Orientation: R
# Hashtag: CNN, Orientation: R
# Hashtag: Globolixo, Orientation: R
# Hashtag: AVozdoButanta, Orientation: L
# Hashtag: TTsNasUrnas, Orientation: L
# Hashtag: BolsoPetista, Orientation: L
# Hashtag: EuVotoEmProjeto, Orientation: N
# Hashtag: ElesNão, Orientation: R
# Hashtag: É, Orientation: L
# Hashtag: O, Orientation: R
# Hashtag: Presidenciais2022, Orientation: L
# Hashtag: Lula13EdegarPretto13, Orientation: L
# Hashtag: debatenaband, Orientation: R
# Hashtag: CiroCresce, Orientation: N
# Hashtag: OcapitaoVaiVencerOladrao, Orientation: L
# Hashtag: Presidente, Orientation: L
# Hashtag: Bozo, Orientation: N
# Hashtag: Itabuna, Orientation: L
# Hashtag: filosofia, Orientation: L
# Hashtag: covid, Orientation: R
# Hashtag: CORRUPTOS, Orientation: L
# Hashtag: NemAlckminNemBolsonaro, Orientation: N
# Hashtag: Twitteréumlixo, Orientation: L
# Hashtag: BolsoPetismo, Orientation: L
# Hashtag: Forabolsonaro, Orientation: L
# Hashtag: justiça, Orientation: L
# Hashtag: direito, Orientation: L
# Hashtag: stf, Orientation: L
# Hashtag: stj, Orientation: L
# Hashtag: militar, Orientation: L
# Hashtag: GuedesFalastrao, Orientation: L
# Hashtag: economia, Orientation: L
# Hashtag: guedes, Orientation: L
# Hashtag: LulaEJeronimo, Orientation: L
# Hashtag: chorapetralhada, Orientation: L
# Hashtag: MatuePraPresidente2023, Orientation: L
# Hashtag: forabozo, Orientation: L
# Hashtag: voltalula, Orientation: L
# Hashtag: lulalá, Orientation: L
# Hashtag: fazoL, Orientation: L
# Hashtag: dfinformado, Orientation: N
# Hashtag: ultimasnoticias, Orientation: N
# Hashtag: df, Orientation: N
# Hashtag: distritofederal, Orientation: N
# Hashtag: mundo, Orientation: N
# Hashtag: alckmin, Orientation: R
# Hashtag: jornalismo, Orientation: R
# Hashtag: en, Orientation: R
# Hashtag: LiberdadeDeExpressao, Orientation: R
# Hashtag: RockInRioMultishow, Orientation: R
# Hashtag: EmicidaNoMultishow, Orientation: R
# Hashtag: souCiro, Orientation: L
# Hashtag: Barroso, Orientation: L
# Hashtag: pisoenfermagem, Orientation: L
# Hashtag: 7desetembrodavergonha, Orientation: L
# Hashtag: centraldaseleições, Orientation: R
# Hashtag: DataFolha, Orientation: L
# Hashtag: EleicoesLimpas, Orientation: R
# Hashtag: loboempeledecordeiro, Orientation: L
# Hashtag: Broxonaro, Orientation: L
# Hashtag: F5Online, Orientation: L
# Hashtag: sarcasmo, Orientation: L
# Hashtag: RompendoAPolarizacao, Orientation: N
# Hashtag: VoteEm1SeLivreDos2, Orientation: N
# Hashtag: SergioMoroNaCadeia, Orientation: L
# Hashtag: JornaldosCanyons, Orientation: L
# Hashtag: JdC, Orientation: L
# Hashtag: ficaemcasa, Orientation: L
# Hashtag: BolsonaroReeleito1ºturno, Orientation: L
# Hashtag: Beyonce, Orientation: L
# Hashtag: ficaadica, Orientation: L
# Hashtag: BolsonaroMetaversoDaCorrupcao, Orientation: L
# Hashtag: Bahia, Orientation: L
# Hashtag: EsquerdaNuncaMais, Orientation: R
# Hashtag: BOMDIA, Orientation: L
# Hashtag: RIR, Orientation: L
# Hashtag: ladrao, Orientation: L
# Hashtag: ciro12, Orientation: N
# Hashtag: ciromereceumachance, Orientation: N
# Hashtag: LulaEmBelem, Orientation: L
# Hashtag: pastor, Orientation: L
# Hashtag: LucianoSubirá, Orientation: L
# Hashtag: ODia, Orientation: L
# Hashtag: g1Rio, Orientation: L
# Hashtag: cpidasfakenews, Orientation: R
# Hashtag: fakenews, Orientation: R
# Hashtag: STE, Orientation: R
# Hashtag: enfermagem, Orientation: R
# Hashtag: TSEVERGONHANACIONAL, Orientation: L
# Hashtag: MENTIROSO, Orientation: L
# Hashtag: CANALHA, Orientation: L
# Hashtag: HIPÓCRITA, Orientation: L
# Hashtag: NÚMERO, Orientation: L
# Hashtag: Genial, Orientation: R
# Hashtag: msnbrasil, Orientation: L
# Hashtag: derrete, Orientation: R
# Hashtag: MelhorSerie, Orientation: L
# Hashtag: QUE, Orientation: L
# Hashtag: Evangelio, Orientation: L
# Hashtag: BolwonaroMentiroso, Orientation: L
# Hashtag: PSOLcomLula13, Orientation: L
# Hashtag: Vote50, Orientation: L
# Hashtag: 51ImoveisComDinheiroVivo, Orientation: L
# Hashtag: pl, Orientation: N
# Hashtag: setedesetembro, Orientation: R
# Hashtag: oglobonaseleicoes, Orientation: L
# Hashtag: OSG, Orientation: L
# Hashtag: Nemlulanembolsonaro, Orientation: L
# Hashtag: ForaMidiaPorca, Orientation: R
# Hashtag: ColetivaAFazenda14, Orientation: L
# Hashtag: Aprizion, Orientation: N
# Hashtag: 1310, Orientation: L
# Hashtag: foralula, Orientation: R
# Hashtag: ForaBolsoLula, Orientation: L
# Hashtag: GoogleAlerts, Orientation: L
# Hashtag: CiroVotoInquebrantavel, Orientation: N
# Hashtag: MoroSenadorPR444, Orientation: L
# Hashtag: Nem, Orientation: L
# Hashtag: 7deSetembro, Orientation: R
# Hashtag: 7deSeptiembre, Orientation: R
# Hashtag: datapovo, Orientation: L
# Hashtag: identidade, Orientation: R
# Hashtag: proposito, Orientation: R
# Hashtag: podcast, Orientation: L
# Hashtag: pessoas, Orientation: R
# Hashtag: missão, Orientation: R
# Hashtag: fazerobem, Orientation: R
# Hashtag: vida, Orientation: R
# Hashtag: conhecimento, Orientation: R
# Hashtag: projetos, Orientation: R
# Hashtag: JornaldaCNN, Orientation: N
# Hashtag: BalançoGeralRJ, Orientation: L
# Hashtag: CiroFujão, Orientation: L
# Hashtag: CORRUPÇAO, Orientation: L
# Hashtag: LULALADRAO, Orientation: L
# Hashtag: DIA, Orientation: L
# Hashtag: 22, Orientation: R
# Hashtag: NUNCAMAIS, Orientation: L
# Hashtag: BROXONARO, Orientation: N
# Hashtag: byMover, Orientation: L
# Hashtag: LouisTomlinson, Orientation: L
# Hashtag: BiggerThanMe, Orientation: L
# Hashtag: FaithInTheFuture, Orientation: L
# Hashtag: Corinthians, Orientation: L
# Hashtag: tiosamnews, Orientation: L
# Hashtag: CNN360, Orientation: L
# Hashtag: DevolveODinheiroJanones, Orientation: L
# Hashtag: Ipec, Orientation: L
# Hashtag: RockinRioNoTikTok, Orientation: L
# Hashtag: Mulher, Orientation: L
# Hashtag: Esquerda, Orientation: L
# Hashtag: Direita, Orientation: L
# Hashtag: globolixo, Orientation: R
# Hashtag: globo, Orientation: L
# Hashtag: BolsonaroOdeiaMulheres, Orientation: L
# Hashtag: CalaBocaEsquerdistaPodre, Orientation: L
# Hashtag: BolsonarosNuncaMais, Orientation: L
# Hashtag: agenda2030, Orientation: L
# Hashtag: KlausSchwab, Orientation: L
# Hashtag: ForaMidiaLixo, Orientation: R
# Hashtag: BolsonaroReeleitoNoPrimeitoTurno, Orientation: R
# Hashtag: repense, Orientation: L
# Hashtag: pas, Orientation: L
# Hashtag: LulaNoJN, Orientation: L
# Hashtag: TebetACIMAdeCiro, Orientation: L
# Hashtag: AbrapelNaMídia, Orientation: L
# Hashtag: UOLNotícias, Orientation: L
# Hashtag: CentraldasEleições, Orientation: L
# Hashtag: amandaklein, Orientation: L
# Hashtag: GENOCIDA, Orientation: L
# Hashtag: cloroquina, Orientation: L
# Hashtag: DesmentindoBolsonaro, Orientation: L
# Hashtag: LulaCorruPTo, Orientation: L
# Hashtag: LulaAmigoDoAmigoDoMeuPai, Orientation: L
# Hashtag: Lulanão, Orientation: L
# Hashtag: DisneyPinóquio, Orientation: L
# Hashtag: BolsonaroLadrão, Orientation: L
# Hashtag: factchecking, Orientation: L
# Hashtag: eua, Orientation: L
# Hashtag: DataRock, Orientation: L
# Hashtag: RockinRio2022, Orientation: L
# Hashtag: TimesNewsPortuguese, Orientation: L
# Hashtag: TimesNews, Orientation: L
# Hashtag: Recife, Orientation: R
# Hashtag: ConexaoGloboNews, Orientation: L
# Hashtag: Estudioi, Orientation: L
# Hashtag: Votoútil, Orientation: L
# Hashtag: AlckminVoltandoaCenaDoCrime, Orientation: L
# Hashtag: CadêOsBilhoes, Orientation: L
# Hashtag: PTPCC, Orientation: L
# Hashtag: Pânico, Orientation: N
# Hashtag: SpaceDos30Dias, Orientation: L
# Hashtag: EiBolsonaroVaiTomarnoCu, Orientation: L
# Hashtag: Trabalhador, Orientation: N
# Hashtag: Auxílio_Brasil, Orientation: N
# Hashtag: Auxílio_Bras, Orientation: N
# Hashtag: EquipeLula, Orientation: L
# Hashtag: BolsoLula, Orientation: L
# Hashtag: AgoraĖCiro, Orientation: L
# Hashtag: lulaoficial, Orientation: R
# Hashtag: 7DeSetembro, Orientation: L
# Hashtag: VotoNulo, Orientation: L
# Hashtag: LulaNaCadeiaDeNovo, Orientation: L
# Hashtag: Bolsonarismo, Orientation: R
# Hashtag: BolsonaroTemRazão, Orientation: R
# Hashtag: 7deSetembroVaiSerGigante, Orientation: L
# Hashtag: SimoneNao, Orientation: L
# Hashtag: OlharDigital, Orientation: L
# Hashtag: Notícia, Orientation: L
# Hashtag: comentarioajuda, Orientation: L
# Hashtag: TMJ22BOLSONAROhttps, Orientation: L
# Hashtag: ChupaEssaManga, Orientation: L
# Hashtag: diadaindependencia, Orientation: L
# Hashtag: irmaospiologo, Orientation: L
# Hashtag: ps5, Orientation: L
# Hashtag: nintendo, Orientation: L
# Hashtag: games, Orientation: R
# Hashtag: jogos, Orientation: N
# Hashtag: xbox, Orientation: L
# Hashtag: partoba, Orientation: L
# Hashtag: fail, Orientation: L
# Hashtag: leandrofrancois, Orientation: N
# Hashtag: ribeiraopreto, Orientation: N
# Hashtag: parafrenteSP, Orientation: N
# Hashtag: sempreemfrente, Orientation: N
# Hashtag: brasileiro, Orientation: R
# Hashtag: brasileira, Orientation: R
# Hashtag: CCRI, Orientation: R
# Hashtag: RCIT, Orientation: R
# Hashtag: Brasil2022, Orientation: R
# Hashtag: STFRompeuADemocracia, Orientation: R
# Hashtag: STFOrganizacaoCriminosa, Orientation: R
# Hashtag: NemLulaNemBolsonaroNemCiro, Orientation: L
# Hashtag: Manaus, Orientation: L
# Hashtag: Amazônia, Orientation: L
# Hashtag: Comício, Orientation: L
# Hashtag: AM, Orientation: L
# Hashtag: BandNewsDifusora, Orientation: L
# Hashtag: BandNewsManaus, Orientation: L
# Hashtag: TarcisioGovernadorSP, Orientation: R
# Hashtag: BOATARDE, Orientation: L
# Hashtag: Estúdioi, Orientation: R
# Hashtag: camarotti, Orientation: L
# Hashtag: prestaçãodecontaspolíticas, Orientation: L
# Hashtag: FechadoComBolsonaro2022, Orientation: R
# Hashtag: FechadoComBolsonaro, Orientation: R
# Hashtag: tribunaldospovos, Orientation: R
# Hashtag: 28GritoDosExcluídos, Orientation: L
# Hashtag: jesus, Orientation: R
# Hashtag: cristao, Orientation: R
# Hashtag: igreja, Orientation: L
# Hashtag: deuseamor, Orientation: R
# Hashtag: enquete, Orientation: N
# Hashtag: SimoneTebet, Orientation: N
# Hashtag: CNNBrasil360, Orientation: N
# Hashtag: JTCultura, Orientation: L
# Hashtag: LinhaDeFrente, Orientation: L
# Hashtag: fiqueemcasacomolula, Orientation: L
# Hashtag: IPESPE, Orientation: N
# Hashtag: 7desetembrovaisergigante, Orientation: R
# Hashtag: ForaBolsonaromentiroso, Orientation: L
# Hashtag: PND, Orientation: N
# Hashtag: VouDeCiro, Orientation: N
# Hashtag: meupresidenteéimbroxável, Orientation: L
# Hashtag: sqn, Orientation: L
# Hashtag: RockinRio, Orientation: L
# Hashtag: MelhorJaIrSeArrependendo, Orientation: L
# Hashtag: dredmarfernandes, Orientation: R
# Hashtag: edmarfernandes22000, Orientation: R
# Hashtag: votecerto, Orientation: R
# Hashtag: vaidar22, Orientation: R
# Hashtag: b22, Orientation: R
# Hashtag: GloriaGroove, Orientation: L
# Hashtag: EduardoBolsonaro, Orientation: L
# Hashtag: STF, Orientation: N
# Hashtag: Dia7VaiSerGigante, Orientation: R
# Hashtag: 2TcomCiro, Orientation: N
# Hashtag: AposentaLula, Orientation: N
# Hashtag: paz, Orientation: R
# Hashtag: RodrigoGarciaGovernador, Orientation: L
# Hashtag: Rodrigo45, Orientation: L
# Hashtag: SPemFrente, Orientation: L
# Hashtag: Janja, Orientation: L
# Hashtag: gafe, Orientation: L
# Hashtag: eleiçoes2022, Orientation: L
# Hashtag: BruxinhaNews, Orientation: L
# Hashtag: Bonner, Orientation: L
# Hashtag: Aboiadavaiestourardia07, Orientation: L
# Hashtag: lulala, Orientation: L
# Hashtag: sitenatelinha, Orientation: L
# Hashtag: simone, Orientation: N
# Hashtag: luladay, Orientation: L
# Hashtag: bolsonaronacadeia, Orientation: L
# Hashtag: Uniao3Colocado, Orientation: L
# Hashtag: ForaMidiaMilitante, Orientation: R
# Hashtag: BOLSONAROATE2026, Orientation: L
# Hashtag: Bolsonaroreleito2022, Orientation: L
# Hashtag: JornaldaBand, Orientation: L
# Hashtag: BandJornalismo, Orientation: L
# Hashtag: CentralSplash, Orientation: L
# Hashtag: EMICIDANOMULTISHOW, Orientation: L
# Hashtag: MDB, Orientation: R
# Hashtag: PL, Orientation: R
# Hashtag: ForaLulaLadrao, Orientation: R
# Hashtag: FECHADO, Orientation: L
# Hashtag: tse, Orientation: R
# Hashtag: MORNINGSHOW, Orientation: L
# Hashtag: CarluxoDoLula, Orientation: L
# Hashtag: Carluxo, Orientation: L
# Hashtag: odioDoBem, Orientation: L
# Hashtag: vassalagem, Orientation: L
# Hashtag: LulaVoltou, Orientation: L
# Hashtag: lulaprimeiroturno, Orientation: L
# Hashtag: Internacional, Orientation: N
# Hashtag: VamosdobrarosvotosdeLula, Orientation: L
# Hashtag: NoticieroVV, Orientation: N
# Hashtag: 3Oct, Orientation: N
# Hashtag: NordesteComBolsonaro, Orientation: R
# Hashtag: TVCultura, Orientation: L
# Hashtag: EnVivo, Orientation: L
# Hashtag: TodasLasVoces, Orientation: L
# Hashtag: Brasile, Orientation: R
# Hashtag: BolsoNey, Orientation: R
# Hashtag: RA, Orientation: L
# Hashtag: ForaTarcísio, Orientation: L
# Hashtag: HaddadGovernador, Orientation: L
# Hashtag: NuevoDía, Orientation: N
# Hashtag: NoticiasFalcón, Orientation: N
# Hashtag: NewsAndInformation, Orientation: L
# Hashtag: elecciones, Orientation: N
# Hashtag: economía, Orientation: N
# Hashtag: finanzas, Orientation: N
# Hashtag: mercosur, Orientation: N
# Hashtag: planreal, Orientation: N
# Hashtag: acuerdouemercosur, Orientation: N
# Hashtag: empresas, Orientation: N
# Hashtag: pymes, Orientation: N
# Hashtag: emprendedores, Orientation: N
# Hashtag: exportaciones, Orientation: N
# Hashtag: importaciones, Orientation: N
# Hashtag: BrasilElige, Orientation: R
# Hashtag: BrasilDecide, Orientation: R
# Hashtag: CNNNASELEICOES, Orientation: L
# Hashtag: 03Oct, Orientation: L
# Hashtag: Entérate, Orientation: L
# Hashtag: LulaNoSegundoTurno, Orientation: L
# Hashtag: Chorizo, Orientation: L
# Hashtag: NDmais, Orientation: L
# Hashtag: brazilelections, Orientation: N
# Hashtag: Brasilien, Orientation: R
# Hashtag: daSilva, Orientation: R
# Hashtag: LulaDeNovoNo2ºTurno, Orientation: L
# Hashtag: VamosDeLulaDeNovo, Orientation: L
# Hashtag: Dia30LulaPresidente, Orientation: L
# Hashtag: EleccionesBrasil2022, Orientation: N
# Hashtag: RegresoAClases, Orientation: L
# Hashtag: FreeAlexSaab, Orientation: L
# Hashtag: navarro2023, Orientation: L
# Hashtag: PINTOAWARD, Orientation: L
# Hashtag: corrientesposit, Orientation: L
# Hashtag: 3ottobre, Orientation: L
# Hashtag: nojo, Orientation: L
# Hashtag: LulaNão, Orientation: R
# Hashtag: Navarro2023, Orientation: L
# Hashtag: LaJornadaOpina, Orientation: N
# Hashtag: Nordeste, Orientation: L
# ...
# Hashtag: QueroAffairCom, Orientation: R
# Hashtag: OutLula, Orientation: R
# Hashtag: VamosALaFilven2022, Orientation: L
# Hashtag: VenezuelaCreceYAvanza, Orientation: L
# Hashtag: cnnportugal, Orientation: R
# Hashtag: Abcnews, Orientation: R
# Hashtag: CBSNews, Orientation: R
# Hashtag: NBCNews, Orientation: R
# Hashtag: Tabata4040, Orientation: L
# Hashtag: 15deNovembro, Orientation: R
# Hashtag: democraciavive, Orientation: L
# Hashtag: MaisVocê, Orientation: L
# Hashtag: Instituição, Orientation: R
# Hashtag: CientistaPolitico, Orientation: R
# Hashtag: Out, Orientation: R
# Hashtag: fazoLagora, Orientation: L
# Hashtag: CodigoFonteHackeado, Orientation: R
# Hashtag: outLula, Orientation: R
# Hashtag: LulaLadrãoSeuLugarENaPrisão, Orientation: N
# Hashtag: Manifest, Orientation: N
# Hashtag: lulapreso, Orientation: N
# Hashtag: lulanão, Orientation: N
# Hashtag: intervencaofederal, Orientation: N
# Hashtag: intervenção, Orientation: N
# Hashtag: brasildefato, Orientation: L
# Hashtag: janja, Orientation: L
# Hashtag: brasilnasruas, Orientation: L
# Hashtag: sosforcasarmadas, Orientation: L
# Hashtag: calandobolsominios, Orientation: L
# Hashtag: cadeobolsonaro, Orientation: L
# Hashtag: SalvemOBrasil, Orientation: L
# Hashtag: quadrilhadopt, Orientation: R
# Hashtag: pccpt, Orientation: R
# Hashtag: invasãodeterra, Orientation: R
# Hashtag: IntervencaoFederalMilitar, Orientation: R
# Hashtag: enem2022, Orientation: R
# Hashtag: World, Orientation: L
# Hashtag: stftraidoresdapatria, Orientation: L
# Hashtag: LulaNaCOP, Orientation: L
# Hashtag: italtimes, Orientation: N
# Hashtag: notizie, Orientation: N
# Hashtag: italia, Orientation: N
# Hashtag: aborto, Orientation: N
# Hashtag: LulaBolsonaro, Orientation: N
# Hashtag: Lultima, Orientation: N
# Hashtag: sfida, Orientation: N
# Hashtag: Viagra, Orientation: N
# Hashtag: Acorda, Orientation: N
# Hashtag: aprende, Orientation: N
# Hashtag: desperta, Orientation: N
# Hashtag: AbusodePoder, Orientation: N
# Hashtag: AbusoDerAutoridade, Orientation: N
# Hashtag: e, Orientation: N
# Hashtag: impunidade, Orientation: N
# Hashtag: STFvergonhaNacional, Orientation: N
# Hashtag: TSEvergonhaNacional, Orientation: N
# Hashtag: CensuraNÃO, Orientation: N
# Hashtag: BASTA, Orientation: N
# Hashtag: acabouporra, Orientation: L
# Hashtag: aceitaquedoimenos, Orientation: L
# Hashtag: QUAL3, Orientation: L
# Hashtag: SorayanoBBB23, Orientation: L
# Hashtag: cop27egypt, Orientation: R
# Hashtag: cop27Egypt2022, Orientation: R
# Hashtag: egito, Orientation: R
# Hashtag: ViralVideo, Orientation: L
# Hashtag: STFVERGONHADOBRASIL, Orientation: R
# Hashtag: BracoForte, Orientation: N
# Hashtag: brazilwasstrolen, Orientation: R
# Hashtag: Militarización, Orientation: L
# Hashtag: smartmatic, Orientation: N
# Hashtag: MPF, Orientation: L
# Hashtag: impeachmentJa, Orientation: L
# Hashtag: CNNnaCOP27, Orientation: L
# Hashtag: POKENUUVEM, Orientation: R
# Hashtag: simonetebet2022, Orientation: R
# Hashtag: cirogomes2022, Orientation: R
# Hashtag: ciro12presidente, Orientation: R
# Hashtag: tebet15, Orientation: R
# Hashtag: simone15, Orientation: R
# Hashtag: ciropresidente12, Orientation: R
# Hashtag: brazilwasstolenbybolsonaro, Orientation: R
# Hashtag: sosforçasarmadas, Orientation: R
# Hashtag: sosforcasarmadassalvemobrasil, Orientation: R
# Hashtag: TodosPeloBrasil, Orientation: L
# Hashtag: EsseÉOCara, Orientation: L
# Hashtag: VemPraRuaBrazil, Orientation: N
# Hashtag: ComeceSeuDia, Orientation: L
# Hashtag: biocombustivel, Orientation: L
# Hashtag: biodiesel, Orientation: L
# Hashtag: soja, Orientation: L
# Hashtag: diesel, Orientation: L
# Hashtag: breakingnews, Orientation: L
# Hashtag: LulaPresidenteELEITO, Orientation: L
# Hashtag: FraudeBrasil, Orientation: R
# Hashtag: nowORnever, Orientation: R
# Hashtag: enem, Orientation: R
# Hashtag: MahmutÖzer, Orientation: L
# Hashtag: TudoPeloDinheiro, Orientation: L
# Hashtag: TenisNaESPN, Orientation: L
# Hashtag: Unidosomosmaisfortesninguemsoltamaodeninguem, Orientation: L
# Hashtag: UkraineRussiaWar, Orientation: L
# Hashtag: Europe, Orientation: L
# Hashtag: China, Orientation: L
# Hashtag: Putin, Orientation: L
# Hashtag: XiJinping, Orientation: L
# Hashtag: Germany, Orientation: L
# Hashtag: Kherson, Orientation: L
# Hashtag: Bali, Orientation: L
# Hashtag: tag, Orientation: L
# Hashtag: ptéisso, Orientation: N
# Hashtag: verme, Orientation: N
# Hashtag: Together4Forests, Orientation: L
# Hashtag: aalmamaishonesta, Orientation: L
# Hashtag: Brezilya, Orientation: L
# Hashtag: braziliansprings, Orientation: N
# Hashtag: sc, Orientation: N
# Hashtag: vino, Orientation: L
# Hashtag: LulaNaCop, Orientation: L
# Hashtag: país, Orientation: R
# Hashtag: brasileiras, Orientation: R
# Hashtag: world, Orientation: N
# Hashtag: foralulaladrão, Orientation: R
# Hashtag: inovação, Orientation: R
# Hashtag: visão, Orientation: R
# Hashtag: brasillivre, Orientation: R
# Hashtag: AquinãosefalamaldoLula, Orientation: L
# Hashtag: AquinãosefalamaldoPT, Orientation: L
# Hashtag: SBTRio, Orientation: L
# Hashtag: Kiev, Orientation: L
# Hashtag: Manipulation, Orientation: R
# Hashtag: BrazilWasStoles, Orientation: R
# Hashtag: facts, Orientation: R
# Hashtag: cop27, Orientation: R
# Hashtag: brazilianspring, Orientation: L
# Hashtag: Gospel, Orientation: R
# Hashtag: FUTEBOL, Orientation: R
# Hashtag: brazilwasstollen, Orientation: R
# Hashtag: Braziliansprring, Orientation: R
# Hashtag: fazuelli, Orientation: L
# Hashtag: Juventude, Orientation: L
# Hashtag: RelembrarÉViver, Orientation: L
# Hashtag: HOY, Orientation: L
# Hashtag: BuenasTardesUruguay, Orientation: L
# Hashtag: RadioUruguay, Orientation: L
# Hashtag: ANISTIANÃO, Orientation: L
# Hashtag: JornalDaCultura, Orientation: L
# Hashtag: Variedades, Orientation: L
# Hashtag: Boicote, Orientation: L
# Hashtag: RespeiteAJanja, Orientation: L
# Hashtag: LAVAJATO, Orientation: L
# Hashtag: QuadrilhaModeON, Orientation: L
# Hashtag: band, Orientation: L
# Hashtag: sbt, Orientation: L
# Hashtag: jovempan, Orientation: R
# Hashtag: lulagettofuck, Orientation: N
# Hashtag: lovebrazil, Orientation: N
# Hashtag: regimemilitar, Orientation: R
# Hashtag: chupaqueacanaedoce, Orientation: L
# Hashtag: Help, Orientation: L
# Hashtag: Republica, Orientation: R
# Hashtag: SOSFFA, Orientation: R
# Hashtag: PatriotasNasRuas, Orientation: R
# Hashtag: VACCINI, Orientation: L
# Hashtag: ForcasArmadas, Orientation: R
# Hashtag: ForaGlobo, Orientation: R
# Hashtag: Covid, Orientation: R
# Hashtag: Covid19, Orientation: R
# Hashtag: abcdjornal, Orientation: L
# Hashtag: diadema, Orientation: L
# Hashtag: transição, Orientation: L
# Hashtag: TROCONUDES, Orientation: L
# Hashtag: Bom, Orientation: L
# Hashtag: Photography, Orientation: L
# Hashtag: Photos, Orientation: L
# Hashtag: Imagens, Orientation: L
# Hashtag: 写真, Orientation: L
# Hashtag: 摄影, Orientation: L
# Hashtag: фотографія, Orientation: L
# Hashtag: FocoAméricaLLYC, Orientation: L
# Hashtag: BrasilianSpring, Orientation: R
# Hashtag: OAmorVenceu, Orientation: R
# Hashtag: Temperaturas, Orientation: L
# Hashtag: SanLuisPotosí, Orientation: L
# Hashtag: Clima, Orientation: L
# Hashtag: PatriotaBrasilJB, Orientation: R
# Hashtag: exercitooficial, Orientation: R
# Hashtag: DireitaReal, Orientation: R
# Hashtag: EuSouConservador, Orientation: R
# Hashtag: MelhorJairSeAcostumando, Orientation: R
# Hashtag: Conservadorismo, Orientation: R
# Hashtag: JuntosSomosMaisFortes, Orientation: R
# Hashtag: EstouComBolsonaro, Orientation: R
# Hashtag: JairMessiasBolsonaro, Orientation: R
# Hashtag: patriota, Orientation: L
# Hashtag: DireitaForte, Orientation: R
# Hashtag: Egypt, Orientation: L
# Hashtag: quemcomporcosanda, Orientation: R
# Hashtag: dizmecomquemtuandas, Orientation: R
# Hashtag: proclamacaodarepublica, Orientation: R
# Hashtag: Odysee, Orientation: L
# Hashtag: janjaNoFantastico, Orientation: L
# Hashtag: lula13pelavidapelobrasil, Orientation: L
# Hashtag: BrazilianSprings, Orientation: R
# Hashtag: Brazilianspring, Orientation: R
# Hashtag: brazilwasstolem, Orientation: R
# Hashtag: brazilelectionsfraude, Orientation: R
# Hashtag: MyTime, Orientation: R
# Hashtag: exercito_oficial, Orientation: R
# Hashtag: marinhadobrasil, Orientation: R
# Hashtag: intervencao, Orientation: R
# Hashtag: luta, Orientation: R
# Hashtag: noticiasmaranhao, Orientation: R
# Hashtag: saoluis, Orientation: R
# Hashtag: slz, Orientation: R
# Hashtag: slzma, Orientation: R
# Hashtag: blogdoezequielslz, Orientation: R
# Hashtag: BreakingNews, Orientation: R
# Hashtag: TuesdayVibes, Orientation: R
# Hashtag: JornaldaTarde, Orientation: L
# Hashtag: novededos, Orientation: R
# Hashtag: NNB, Orientation: L
# Hashtag: monarknostf, Orientation: L
# Hashtag: populismo, Orientation: L
# Hashtag: NOTICIASFULERAGENS, Orientation: L
# Hashtag: notíciasfuleragens, Orientation: L
# Hashtag: imprensa, Orientation: L
# Hashtag: viagra, Orientation: L
# Hashtag: fera2023, Orientation: L
# Hashtag: CristianoRonaldo, Orientation: R
# Hashtag: Cargo, Orientation: L
# Hashtag: temer, Orientation: L
# Hashtag: sostenes, Orientation: L
# Hashtag: silasmalafaia, Orientation: L
# Hashtag: JornalDaki, Orientation: N
# Hashtag: Investigação, Orientation: L
# Hashtag: leis, Orientation: L
# Hashtag: PecadoCapitalNoGloboPlay, Orientation: L
# Hashtag: petistatemquesefoder, Orientation: L
# Hashtag: UltimaHora, Orientation: N
# Hashtag: AHORA24H, Orientation: N
# Hashtag: NowWatching, Orientation: N
# Hashtag: NEWYORK, Orientation: N
# Hashtag: ElectionDay, Orientation: N
# Hashtag: novayork, Orientation: L
# Hashtag: ElCallaoMereceMás, Orientation: L
# Hashtag: LosHonestosSomosMás, Orientation: L
# Hashtag: FraudeElectoral, Orientation: R
# Hashtag: BoricValeCallampa, Orientation: R
# Hashtag: LulaPresidenteEleito, Orientation: L
# Hashtag: RespeiteMeuVoto, Orientation: L
# Hashtag: jusoor_post, Orientation: L
# Hashtag: quemmandoumatarbolsonaro, Orientation: L
# Hashtag: balancogeralrj, Orientation: L
# Hashtag: SoundCloud, Orientation: L
# Hashtag: Desenvolvimento, Orientation: N
# Hashtag: EstadosUnidos, Orientation: N
# Hashtag: business, Orientation: N
# Hashtag: ordemparanormal, Orientation: L
# Hashtag: rpgdemesa, Orientation: L
# Hashtag: sinaisdooutrolado, Orientation: L
# Hashtag: despertadosrpg, Orientation: L
# Hashtag: BrasilDoFuturo, Orientation: L
# Hashtag: angelaalves, Orientation: L
# Hashtag: Ministro, Orientation: L
# Hashtag: LulaLiderMundial, Orientation: L
# Hashtag: Podcast, Orientation: L
# Hashtag: BarrosoAdvogaduzinhoCorruptoECriminoso, Orientation: L
# Hashtag: corrupcaomata, Orientation: N
# Hashtag: AquecimentoGlobal, Orientation: L
# Hashtag: Desmatamento, Orientation: L
# Hashtag: GovernoBolsonaro, Orientation: L
# Hashtag: GovernoLula, Orientation: L
# Hashtag: UnContinenteEnDisputa, Orientation: L
# Hashtag: fizibilite, Orientation: L
# Hashtag: lokasyonanalizi, Orientation: L
# Hashtag: pazararastirmasi, Orientation: L
# Hashtag: locationanalytics, Orientation: L
# Hashtag: yersecimi, Orientation: L
# Hashtag: data, Orientation: L
# Hashtag: türkiye, Orientation: L
# Hashtag: analytic, Orientation: L
# Hashtag: veribilimi, Orientation: L
# Hashtag: veritabanı, Orientation: L
# Hashtag: nextgeo, Orientation: L
# Hashtag: istatistik, Orientation: L
# Hashtag: perakende, Orientation: L
# Hashtag: sektör, Orientation: L
# Hashtag: satış, Orientation: L
# Hashtag: gıda, Orientation: L
# Hashtag: tekstil, Orientation: L
# Hashtag: tıbbiürün, Orientation: L
# Hashtag: otomotiv, Orientation: L
# Hashtag: tüik, Orientation: L
# Hashtag: veri, Orientation: L
# Hashtag: Comércio, Orientation: R
# Hashtag: construção, Orientation: R
# Hashtag: defesa, Orientation: R
# Hashtag: eleit, Orientation: R
# Hashtag: FFAAHEROICOS, Orientation: L
# Hashtag: proclamaçãodarepública, Orientation: L
# Hashtag: BrazilWasCensored, Orientation: L
# Hashtag: CensuraNão, Orientation: L
# Hashtag: blackfriday2022, Orientation: R
# Hashtag: FLA127, Orientation: R
# Hashtag: forex, Orientation: L
# Hashtag: fx, Orientation: L
# Hashtag: sosbos, Orientation: L
# Hashtag: fr4ude, Orientation: R
# Hashtag: LulaNaCop27, Orientation: L
# Hashtag: LulanaCOP27, Orientation: L
# Hashtag: JohnKerry, Orientation: L
# Hashtag: poptimepetista, Orientation: R
# Hashtag: BuenosAires, Orientation: N
# Hashtag: kallenparapresidente, Orientation: L
# Hashtag: JornalDaManha, Orientation: L
# Hashtag: honesto, Orientation: N
# Hashtag: fanatismo, Orientation: N
# Hashtag: autoenganação, Orientation: N
# Hashtag: Brasilistão, Orientation: N
# Hashtag: BOLSONAROREELEITOEM2022, Orientation: L
# Hashtag: CHEGA, Orientation: L
# Hashtag: SOMOSTODOSCIRO, Orientation: L
# Hashtag: postagem, Orientation: R
# Hashtag: SóCiroAmeaçaLula, Orientation: L
# Hashtag: chegadesses2, Orientation: L
# Hashtag: gritodosexcluidos, Orientation: L
# Hashtag: gritodosexcluídoseexcluídas, Orientation: L
# Hashtag: foramagnomalta, Orientation: L
# Hashtag: negocios, Orientation: N
# Hashtag: marketingdigital, Orientation: N
# Hashtag: marketing, Orientation: N
# Hashtag: TricolorNaConmebolTV, Orientation: L
# Hashtag: CiroNao, Orientation: L
# Hashtag: CiroEBolsonarista, Orientation: L
# Hashtag: patrimoniobolsonaro, Orientation: L
# Hashtag: sorayathronicke, Orientation: N
# Hashtag: 200mais, Orientation: L
# Hashtag: FolhaVitoria, Orientation: N
# Hashtag: CiroSP, Orientation: N
# Hashtag: BolsonaroGenocia, Orientation: R
# Hashtag: CUT, Orientation: R
# Hashtag: GloriaADeux, Orientation: L
# Hashtag: vote22Bolsonaro, Orientation: L
# Hashtag: HojeEmDia, Orientation: L
# Hashtag: JC, Orientation: L
# Hashtag: repeitoademocracia, Orientation: N
# Hashtag: GADO, Orientation: L
# Hashtag: LULAPRESIDENTE2023, Orientation: L
# Hashtag: LulaOGritoDeAmorPeloBrasil, Orientation: L
# Hashtag: Elixão2022, Orientation: L
# Hashtag: HomemAranha, Orientation: N
# Hashtag: FridayVibes, Orientation: L
# Hashtag: feriadonacional, Orientation: L
# Hashtag: 07desetembro, Orientation: L
# Hashtag: vivademocracia, Orientation: L
# Hashtag: ELESNÃO, Orientation: L
# Hashtag: acordabrasil, Orientation: L
# Hashtag: Resistencia1614Dias, Orientation: L
# Hashtag: Esmeralda, Orientation: L
# Hashtag: 7DeSetembroVaiSerGigante2, Orientation: L
# Hashtag: DataFolhaUmaVergonha, Orientation: L
# Hashtag: ForaBarroso, Orientation: L
# Hashtag: ForaBolsonaroUrgente, Orientation: L
# Hashtag: CiroNoSegundoTurno, Orientation: N
# Hashtag: buenosaires, Orientation: L
# Hashtag: ba, Orientation: L
# Hashtag: christinaKirchner, Orientation: L
# Hashtag: BicentenarioDaIndependencia, Orientation: L
# Hashtag: Troux, Orientation: L
# Hashtag: VotaCiro12, Orientation: N
# Hashtag: LulaSabeGovernar, Orientation: L
# Hashtag: MeioAmbiente, Orientation: L
# Hashtag: jornalNacional, Orientation: L
# Hashtag: BrunoCarazza, Orientation: L
# Hashtag: primeiroturno, Orientation: R
# Hashtag: 7setembro, Orientation: L
# Hashtag: babaninha, Orientation: L
# Hashtag: voudeciro12, Orientation: L
# Hashtag: LulaAmarelou, Orientation: L
# Hashtag: DigaNãoaPolarizaçãoIdeológica, Orientation: L
# Hashtag: prontofalei, Orientation: L
# Hashtag: Allison, Orientation: L
# Hashtag: Anamosa, Orientation: L
# Hashtag: Arispe, Orientation: L
# Hashtag: Arnolds, Orientation: L
# Hashtag: Ashton, Orientation: L
# Hashtag: Aspinwall, Orientation: L
# Hashtag: Afonso, Orientation: L
# Hashtag: Altinho, Orientation: L
# Hashtag: Amaraji, Orientation: L
# Hashtag: Amparo, Orientation: L
# Hashtag: Araçagi, Orientation: L
# Hashtag: Araçaí, Orientation: L
# Hashtag: Arnold, Orientation: L
# Hashtag: Aspers, Orientation: L
# Hashtag: Aston, Orientation: L
# Hashtag: Atglen, Orientation: L
# Hashtag: Arbutus, Orientation: L
# Hashtag: Agawam, Orientation: L
# Hashtag: DataMathanosInforma, Orientation: L
# Hashtag: ElaSim, Orientation: L
# Hashtag: EssesTrêsNão, Orientation: L
# Hashtag: Bolsonaro22PresidenteReeleito, Orientation: L
# Hashtag: bolsonarovergonhadobrasil, Orientation: L
# Hashtag: 7DeSetembroVaiSerGritante, Orientation: R
# Hashtag: OsAnéisDePoder, Orientation: L
# Hashtag: TheRingsOfPower, Orientation: L
# Hashtag: OchoroélivrePtezada, Orientation: L
# Hashtag: FazOL, Orientation: L
# Hashtag: EuAchoÉPouco, Orientation: L
# Hashtag: OBrasilÉBolsonaro, Orientation: R
# Hashtag: FalaSerio, Orientation: R
# Hashtag: CiroUnicaVia, Orientation: R
# Hashtag: TchuthucaDoCentrao, Orientation: L
# Hashtag: HomerSimpson, Orientation: L
# Hashtag: Lulapresidente13, Orientation: L
# Hashtag: teologianegra, Orientation: L
# Hashtag: cristãoscontraofascismo, Orientation: L
# Hashtag: iPhone14Pro, Orientation: L
# Hashtag: Manifestações7DeSetembro, Orientation: L
# Hashtag: TáCaroCulpaDoBolsonaro, Orientation: L
# Hashtag: DesisteLula, Orientation: R
# Hashtag: stfvergonha, Orientation: L

# %% [markdown]
# Salvando as hastags caracterizadas em um arquivo 'csv'

# %%
# Escreva a lista de dados em um arquivo CSV
with open(arq, mode="w", encoding="utf-8") as arquivo_csv:
    escritor_csv = csv.writer(arquivo_csv, delimiter=",")

    # Escreva cada linha da lista como uma linha no arquivo CSV
    for linha in lista_csv:
        if any(linha):
            escritor_csv.writerow(linha)
